# %%
import os
os.listdir("../../data/chatgpt/LeyDatosPersonales.pdf")
# Out:
# ['LeyDatosPersonales.pdf']

# %%
import pandas as pd
pd.read_csv("C:/Users/usuario/Documents/GitHub/DataGlobal/data/chatgpt/dominios/datos.csv").head()
# Out:
#   Macrodominio                     Hoja  Division  \
# 0     Clientes  Detalle Campos Personas  Personas
# 1     Clientes  Detalle Campos Personas  Personas
# 2     Clientes  Detalle Campos Personas  Personas
# 3     Clientes  Detalle Campos Personas  Personas
# 4     Clientes  Detalle Campos Personas  Personas
#
#                                     DescripcionCampo  \
# 0  Es el nombre de la agencia. en donde un client...
# 1  Nombre de la agencia donde se creó el cliente ...
# 2  El valor de la marca es '1' o 'Null'. '1' para...
# 3          Indica el año de fabricación del vehículo
# 4                    Apellidos y nombres del Cónyuge
#
#   InfoTecnicaServidorFuenteOficial InfoTecnicaBaseDatosFuenteOficial  \
# 0                 ECBPPRQ121.11124                        BDDELIVERY
# 1     BANCS REFERENCE 10.70.136.35                           FNSONLP
# 2                              NaN                               NaN
# ...
