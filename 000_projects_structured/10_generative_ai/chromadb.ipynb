# %%
import chromadb
client = chromadb.HttpClient()
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\usuario\anaconda3\envs\env_101\Lib\site-packages\httpx\_transports\default.py:69, in map_httpcore_exceptions()
#      68 try:
# ---> 69     yield
#      70 except Exception as exc:
#
# File c:\Users\usuario\anaconda3\envs\env_101\Lib\site-packages\httpx\_transports\default.py:233, in HTTPTransport.handle_request(self, request)
#     232 with map_httpcore_exceptions():
# --> 233     resp = self._pool.handle_request(req)
#     235 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\usuario\anaconda3\envs\env_101\Lib\site-packages\httpcore\_sync\connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
# ...

# %%
# https://github.com/jeffheaton/app_generative_ai/blob/main/t81_559_class_06_2_chromadb.ipynb
