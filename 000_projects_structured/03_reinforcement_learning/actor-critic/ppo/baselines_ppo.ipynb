# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import random
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.vec_env import DummyVecEnv
import tkinter as tk
from tkinter import messagebox


class TTTBoard(object):
    def __init__(self):
        self.board = [0] * 9

    def get_board(self):
        return self.board

    def get_empty_pos(self):
        return [index for index, value in enumerate(self.board) if value == 0]

    def set_move(self, player_order, move):
        self.board[move] = player_order

    def is_over(self):
        board = self.board
        lines = [
            board[0:3], board[3:6], board[6:9],          # Filas
            board[0:9:3], board[1:9:3], board[2:9:3],    # Columnas
            [board[0], board[4], board[8]],              # Diagonal principal
            [board[2], board[4], board[6]]               # Diagonal secundaria
        ]
        for line in lines:
            if abs(sum(line)) == 3:
                return True, np.sign(sum(line))
        if 0 not in board:
            return True, 0  # Empate
        return False, None

    def __str__(self):
        symbols = {1: 'X', -1: 'O', 0: '.'}
        board = [symbols[value] for value in self.board]
        return f"{board[0]} | {board[1]} | {board[2]}\n--+---+--\n{board[3]} | {board[4]} | {board[5]}\n--+---+--\n{board[6]} | {board[7]} | {board[8]}\n"

# %%
class TicTacToeEnv(gym.Env):
    def __init__(self, opponent='random'):
        super(TicTacToeEnv, self).__init__()

        self.action_space = spaces.Discrete(9)
        self.observation_space = spaces.Box(low=-1, high=1, shape=(9,), dtype=np.int32)

        self.agent_player = 1  # El agente siempre es '1' (X)
        self.opponent = opponent  # Puede ser 'random' o 'human'
        self.human_move = None  # Variable para almacenar el movimiento del humano
        self.reset()

    def reset(self, seed=None, options=None):
        self.board = TTTBoard()
        self.current_player = random.choice([1, -1])  # Inicia aleatoriamente
        return np.array(self.board.get_board()), {}

    def step(self, action):
        if action is None:
            # Si no se proporciona una acción, simplemente retornamos el estado actual
            return np.array(self.board.get_board()), 0, False, False, {}

        if self.board.get_board()[action] != 0:
            # Penalizamos la acción inválida
            return np.array(self.board.get_board()), -2, False, False, {}

        # Movimiento del jugador actual (agente)
        self.board.set_move(self.current_player, action)

        # Verificamos si el juego ha terminado
        done, winner = self.board.is_over()
        if done:
            reward = self.calculate_reward(winner)
            return np.array(self.board.get_board()), reward, done, False, {}

        # Cambiamos al otro jugador
        self.current_player *= -1

        # Turno del oponente
        if self.current_player == -self.agent_player:
            if self.opponent == 'random':
                opponent_move = random.choice(self.board.get_empty_pos())
            elif self.opponent == 'human':
                # Obtenemos el movimiento del humano mediante Tkinter
                opponent_move = self.get_human_move_via_tkinter()
                if opponent_move is None:
                    # El humano cerró la ventana sin hacer un movimiento
                    print("El humano no realizó un movimiento. Fin del juego.")
                    done = True
                    reward = self.calculate_reward(self.agent_player)  # El agente gana
                    return np.array(self.board.get_board()), reward, done, False, {}
            else:
                raise ValueError("Tipo de oponente inválido")

            # Movimiento del oponente
            self.board.set_move(self.current_player, opponent_move)

            # Verificamos nuevamente si el juego ha terminado
            done, winner = self.board.is_over()
            if done:
                reward = self.calculate_reward(winner)
                return np.array(self.board.get_board()), reward, done, False, {}

            # Cambiamos de nuevo al agente
            self.current_player *= -1

        # No hay recompensa todavía
        return np.array(self.board.get_board()), 0, False, False, {}

    def calculate_reward(self, winner):
        if winner == self.agent_player:
            return 1  # Victoria
        elif winner == -self.agent_player:
            return -1  # Derrota
        else:
            return 0.5  # Empate

    def render(self):
        print(self.board)

    def close(self):
        pass

    def get_human_move_via_tkinter(self):
        # Crear la ventana de Tkinter
        root = tk.Tk()
        root.title("Tic Tac Toe - Turno del Humano")

        # Inicializamos 'human_move' como None
        self.human_move = None

        # Función callback para los botones
        def on_button_click(i):
            if self.board.get_board()[i] == 0:
                self.human_move = i
                root.destroy()
            else:
                messagebox.showwarning("Movimiento inválido", "Esa celda ya está ocupada.")

        # Crear botones para cada celda
        buttons = []
        for i in range(9):
            btn_text = ''
            state = 'normal'
            if self.board.get_board()[i] == 1:
                btn_text = 'X'
                state = 'disabled'
            elif self.board.get_board()[i] == -1:
                btn_text = 'O'
                state = 'disabled'
            button = tk.Button(root, text=btn_text, font=('normal', 60), width=2, height=1,
                               state=state,
                               command=lambda i=i: on_button_click(i))
            buttons.append(button)

        # Organizar los botones en una cuadrícula
        for i in range(9):
            row = i // 3
            col = i % 3
            buttons[i].grid(row=row, column=col)

        # Iniciar el bucle principal de Tkinter y esperar hasta que se cierre la ventana
        root.mainloop()

        return self.human_move

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

# Crear el entorno con el oponente aleatorio
env = TicTacToeEnv(opponent='random')

# Verificar el entorno
check_env(env)

# Crear y entrenar el modelo PPO
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=1000000)

# Guardar el modelo entrenado
model.save("ppo_tictactoe_1M")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 9.2      |
# |    ep_rew_mean     | -9.63    |
# | time/              |          |
# |    fps             | 803      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.35        |
# |    ep_rew_mean          | -8.33       |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 2           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008421451 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | -0.000638   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 59          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.51        |
# |    ep_rew_mean          | -10.1       |
# | time/                   |             |
# |    fps                  | 552         |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009197816 |
# |    clip_fraction        | 0.0729      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | -0.0626     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 45.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.59        |
# |    ep_rew_mean          | -8.47       |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 4           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009339508 |
# |    clip_fraction        | 0.0641      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | -0.0256     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 58          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.15        |
# |    ep_rew_mean          | -9.34       |
# | time/                   |             |
# |    fps                  | 510         |
# |    iterations           | 5           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009649634 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -0.0109     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 80.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.97        |
# |    ep_rew_mean          | -11.2       |
# | time/                   |             |
# |    fps                  | 498         |
# |    iterations           | 6           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009813989 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -0.206      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 59.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.73        |
# |    ep_rew_mean          | -8.87       |
# | time/                   |             |
# |    fps                  | 492         |
# |    iterations           | 7           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008679733 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | 0.000475    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 93.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.69         |
# |    ep_rew_mean          | -8.9         |
# | time/                   |              |
# |    fps                  | 488          |
# |    iterations           | 8            |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0074862475 |
# |    clip_fraction        | 0.0371       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | -0.0432      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 88.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.07        |
# |    ep_rew_mean          | -9.46       |
# | time/                   |             |
# |    fps                  | 483         |
# |    iterations           | 9           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.007964237 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.15       |
# |    explained_variance   | -0.0998     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.5        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 85.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.12        |
# |    ep_rew_mean          | -9.47       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 10          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007946902 |
# |    clip_fraction        | 0.041       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | -0.00596    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 73.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.92         |
# |    ep_rew_mean          | -9.29        |
# | time/                   |              |
# |    fps                  | 476          |
# |    iterations           | 11           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0088182185 |
# |    clip_fraction        | 0.0591       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.15        |
# |    explained_variance   | 0.0366       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.9         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 74.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 7.91         |
# |    ep_rew_mean          | -7.22        |
# | time/                   |              |
# |    fps                  | 475          |
# |    iterations           | 12           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0097656865 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | -0.0226      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 48.4         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0151      |
# |    value_loss           | 74.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.15        |
# |    ep_rew_mean          | -7.93       |
# | time/                   |             |
# |    fps                  | 474         |
# |    iterations           | 13          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009548357 |
# |    clip_fraction        | 0.0558      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | -0.00461    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.8        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 78.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.96        |
# |    ep_rew_mean          | -7.63       |
# | time/                   |             |
# |    fps                  | 473         |
# |    iterations           | 14          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.010135325 |
# |    clip_fraction        | 0.0839      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.00919     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.019      |
# |    value_loss           | 61.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.42        |
# |    ep_rew_mean          | -8.1        |
# | time/                   |             |
# |    fps                  | 472         |
# |    iterations           | 15          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009098813 |
# |    clip_fraction        | 0.0618      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.14       |
# |    explained_variance   | 0.0516      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 56          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.86        |
# |    ep_rew_mean          | -9.27       |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 16          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009976139 |
# |    clip_fraction        | 0.0833      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.0014      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.8        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 51.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.69        |
# |    ep_rew_mean          | -7.13       |
# | time/                   |             |
# |    fps                  | 471         |
# |    iterations           | 17          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.009139169 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.00179     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 53.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.38        |
# |    ep_rew_mean          | -8.44       |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 18          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.008894978 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.126       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 73.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.99        |
# |    ep_rew_mean          | -9.38       |
# | time/                   |             |
# |    fps                  | 470         |
# |    iterations           | 19          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.009719583 |
# |    clip_fraction        | 0.0786      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.0734      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0155     |
# |    value_loss           | 85.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.19        |
# |    ep_rew_mean          | -9.97       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 20          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010659738 |
# |    clip_fraction        | 0.0947      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.00633     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.6        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0202     |
# |    value_loss           | 67.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.98        |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 469         |
# |    iterations           | 21          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010961468 |
# |    clip_fraction        | 0.0858      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.0649      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.1        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 70.8        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 8.55       |
# |    ep_rew_mean          | -8.69      |
# | time/                   |            |
# |    fps                  | 469        |
# |    iterations           | 22         |
# |    time_elapsed         | 96         |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00939393 |
# |    clip_fraction        | 0.0477     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.1       |
# |    explained_variance   | -0.141     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 44.8       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.0125    |
# |    value_loss           | 103        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.54        |
# |    ep_rew_mean          | -8.51       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 23          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.009510711 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.0452      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 66.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.73        |
# |    ep_rew_mean          | -9.22       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 24          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.011383712 |
# |    clip_fraction        | 0.0918      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.0105      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 72.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.15        |
# |    ep_rew_mean          | -7.92       |
# | time/                   |             |
# |    fps                  | 468         |
# |    iterations           | 25          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.011154402 |
# |    clip_fraction        | 0.0932      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.12       |
# |    explained_variance   | 0.0458      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 40          |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 67.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | -11.7        |
# | time/                   |              |
# |    fps                  | 468          |
# |    iterations           | 26           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0099502215 |
# |    clip_fraction        | 0.0869       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.0773       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.3         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.0182      |
# |    value_loss           | 63.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.25        |
# |    ep_rew_mean          | -8.08       |
# | time/                   |             |
# |    fps                  | 467         |
# |    iterations           | 27          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010247086 |
# |    clip_fraction        | 0.0859      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.0768      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.1        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0184     |
# |    value_loss           | 75.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.52         |
# |    ep_rew_mean          | -10.1        |
# | time/                   |              |
# |    fps                  | 466          |
# |    iterations           | 28           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0129241925 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.11        |
# |    explained_variance   | -0.088       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.6         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.0194      |
# |    value_loss           | 46.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.86        |
# |    ep_rew_mean          | -7.45       |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 29          |
# |    time_elapsed         | 127         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011299947 |
# |    clip_fraction        | 0.0646      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.139       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 49.3        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 118         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.23        |
# |    ep_rew_mean          | -8.31       |
# | time/                   |             |
# |    fps                  | 465         |
# |    iterations           | 30          |
# |    time_elapsed         | 131         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.011669876 |
# |    clip_fraction        | 0.0696      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | -0.397      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.7        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 58.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 9.08         |
# |    ep_rew_mean          | -9.65        |
# | time/                   |              |
# |    fps                  | 464          |
# |    iterations           | 31           |
# |    time_elapsed         | 136          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0080426335 |
# |    clip_fraction        | 0.0538       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.194        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.6         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0133      |
# |    value_loss           | 74           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.5         |
# |    ep_rew_mean          | -6.74       |
# | time/                   |             |
# |    fps                  | 464         |
# |    iterations           | 32          |
# |    time_elapsed         | 141         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.011219588 |
# |    clip_fraction        | 0.0762      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.205       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 108         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.52        |
# |    ep_rew_mean          | -6.76       |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 33          |
# |    time_elapsed         | 145         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008579424 |
# |    clip_fraction        | 0.0518      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.12        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.9        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 88.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.51        |
# |    ep_rew_mean          | -6.65       |
# | time/                   |             |
# |    fps                  | 463         |
# |    iterations           | 34          |
# |    time_elapsed         | 150         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.011275036 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | 0.0871      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37          |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 66.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.65        |
# |    ep_rew_mean          | -6.79       |
# | time/                   |             |
# |    fps                  | 459         |
# |    iterations           | 35          |
# |    time_elapsed         | 155         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011413276 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.00666     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.6        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 56.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.78        |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 36          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010577913 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.0497      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.5        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0185     |
# |    value_loss           | 47.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.64        |
# |    ep_rew_mean          | -8.74       |
# | time/                   |             |
# |    fps                  | 458         |
# |    iterations           | 37          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.014074154 |
# |    clip_fraction        | 0.0791      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.173       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.2        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 87.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.27        |
# |    ep_rew_mean          | -6.36       |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 38          |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.009904666 |
# |    clip_fraction        | 0.0724      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.0892      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.9        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 69.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.83        |
# |    ep_rew_mean          | -7.33       |
# | time/                   |             |
# |    fps                  | 457         |
# |    iterations           | 39          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.011468883 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.127       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.2        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 67.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.02        |
# |    ep_rew_mean          | -7.46       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 40          |
# |    time_elapsed         | 179         |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.012700857 |
# |    clip_fraction        | 0.078       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.0991      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29.6        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0179     |
# |    value_loss           | 73.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.07        |
# |    ep_rew_mean          | -5.59       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 41          |
# |    time_elapsed         | 184         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010593634 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.1        |
# |    explained_variance   | 0.0215      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.7        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0197     |
# |    value_loss           | 51.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.74        |
# |    ep_rew_mean          | -8.87       |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 42          |
# |    time_elapsed         | 188         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011310991 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.09       |
# |    explained_variance   | 0.0892      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.6        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0207     |
# |    value_loss           | 64.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.09        |
# |    ep_rew_mean          | -6.01       |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 43          |
# |    time_elapsed         | 193         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.013067663 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.287       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.1        |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 66.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.25        |
# |    ep_rew_mean          | -6.08       |
# | time/                   |             |
# |    fps                  | 454         |
# |    iterations           | 44          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010547744 |
# |    clip_fraction        | 0.0954      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.148       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.3        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0199     |
# |    value_loss           | 63.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.69        |
# |    ep_rew_mean          | -6.66       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 45          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011348408 |
# |    clip_fraction        | 0.0928      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.06       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.1        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 68.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.39        |
# |    ep_rew_mean          | -10.3       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 46          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011450039 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.05       |
# |    explained_variance   | 0.199       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 53          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.27         |
# |    ep_rew_mean          | -4.08        |
# | time/                   |              |
# |    fps                  | 453          |
# |    iterations           | 47           |
# |    time_elapsed         | 212          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0126188435 |
# |    clip_fraction        | 0.0966       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.04        |
# |    explained_variance   | 0.244        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 45           |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0191      |
# |    value_loss           | 94.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.89        |
# |    ep_rew_mean          | -7.25       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 48          |
# |    time_elapsed         | 216         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011782453 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.04       |
# |    explained_variance   | 0.248       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.7        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0225     |
# |    value_loss           | 59.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.09        |
# |    ep_rew_mean          | -6.03       |
# | time/                   |             |
# |    fps                  | 452         |
# |    iterations           | 49          |
# |    time_elapsed         | 221         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.021418674 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.222       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.5        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 48.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.57        |
# |    ep_rew_mean          | -5.2        |
# | time/                   |             |
# |    fps                  | 451         |
# |    iterations           | 50          |
# |    time_elapsed         | 226         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.011768059 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2          |
# |    explained_variance   | 0.233       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.7        |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.5         |
# |    ep_rew_mean          | -4.39       |
# | time/                   |             |
# |    fps                  | 451         |
# |    iterations           | 51          |
# |    time_elapsed         | 231         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.011115592 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.5        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 54.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.11        |
# |    ep_rew_mean          | -3.85       |
# | time/                   |             |
# |    fps                  | 451         |
# |    iterations           | 52          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.011933455 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.295       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.2        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0249     |
# |    value_loss           | 50.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6           |
# |    ep_rew_mean          | -3.74       |
# | time/                   |             |
# |    fps                  | 451         |
# |    iterations           | 53          |
# |    time_elapsed         | 240         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.012197269 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.01       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0216     |
# |    value_loss           | 44.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 6.43         |
# |    ep_rew_mean          | -4.73        |
# | time/                   |              |
# |    fps                  | 451          |
# |    iterations           | 54           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0127592515 |
# |    clip_fraction        | 0.141        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.99        |
# |    explained_variance   | 0.0889       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.1         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0247      |
# |    value_loss           | 35.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.47        |
# |    ep_rew_mean          | -4.59       |
# | time/                   |             |
# |    fps                  | 450         |
# |    iterations           | 55          |
# |    time_elapsed         | 250         |
# |    total_timesteps      | 112640      |
# | train/                  |             |
# |    approx_kl            | 0.011881186 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.97       |
# |    explained_variance   | 0.257       |
# |    learning_rate        | 0.0003      |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 3.72         |
# |    ep_rew_mean          | 0.935        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 472          |
# |    time_elapsed         | 2267         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0038566778 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | 0.0164       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0279       |
# |    n_updates            | 4710         |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 0.0779       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.73        |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 473         |
# |    time_elapsed         | 2272        |
# |    total_timesteps      | 968704      |
# | train/                  |             |
# |    approx_kl            | 0.008020931 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.2        |
# |    explained_variance   | -0.0328     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0307      |
# |    n_updates            | 4720        |
# |    policy_gradient_loss | -0.00583    |
# |    value_loss           | 0.0712      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.68         |
# |    ep_rew_mean          | 1            |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 474          |
# |    time_elapsed         | 2276         |
# |    total_timesteps      | 970752       |
# | train/                  |              |
# |    approx_kl            | 0.0059217047 |
# |    clip_fraction        | 0.0525       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.231       |
# |    explained_variance   | 0.0964       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00583      |
# |    n_updates            | 4730         |
# |    policy_gradient_loss | -0.00614     |
# |    value_loss           | 0.0776       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.68         |
# |    ep_rew_mean          | 0.94         |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 475          |
# |    time_elapsed         | 2281         |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0039439755 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.223       |
# |    explained_variance   | 0.231        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00376     |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.00679     |
# |    value_loss           | 0.175        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.67        |
# |    ep_rew_mean          | 0.975       |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 476         |
# |    time_elapsed         | 2286        |
# |    total_timesteps      | 974848      |
# | train/                  |             |
# |    approx_kl            | 0.004195807 |
# |    clip_fraction        | 0.0387      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.229      |
# |    explained_variance   | 0.147       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0864      |
# |    n_updates            | 4750        |
# |    policy_gradient_loss | -0.0087     |
# |    value_loss           | 0.158       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.69         |
# |    ep_rew_mean          | 0.955        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 477          |
# |    time_elapsed         | 2291         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0042335186 |
# |    clip_fraction        | 0.038        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0.102        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0354       |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.0068      |
# |    value_loss           | 0.0707       |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 4.03       |
# |    ep_rew_mean          | 0.1        |
# | time/                   |            |
# |    fps                  | 426        |
# |    iterations           | 478        |
# |    time_elapsed         | 2295       |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.00385964 |
# |    clip_fraction        | 0.0415     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.217     |
# |    explained_variance   | 0.246      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0192     |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.0164    |
# |    value_loss           | 1.75       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.71         |
# |    ep_rew_mean          | 0.97         |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 479          |
# |    time_elapsed         | 2300         |
# |    total_timesteps      | 980992       |
# | train/                  |              |
# |    approx_kl            | 0.0043725516 |
# |    clip_fraction        | 0.0324       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.247       |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.9         |
# |    n_updates            | 4780         |
# |    policy_gradient_loss | -0.00542     |
# |    value_loss           | 21.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.76        |
# |    ep_rew_mean          | 0.935       |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 480         |
# |    time_elapsed         | 2305        |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.010148099 |
# |    clip_fraction        | 0.056       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.204      |
# |    explained_variance   | -0.438      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0276     |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.00846    |
# |    value_loss           | 0.0625      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.73         |
# |    ep_rew_mean          | 0.945        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 481          |
# |    time_elapsed         | 2309         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 0.0039804587 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.212       |
# |    explained_variance   | 0.0463       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0122      |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.00478     |
# |    value_loss           | 0.061        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.74        |
# |    ep_rew_mean          | 0.87        |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 482         |
# |    time_elapsed         | 2314        |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.007934183 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.0908      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00359     |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.00875    |
# |    value_loss           | 0.057       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.89        |
# |    ep_rew_mean          | 0.895       |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 483         |
# |    time_elapsed         | 2318        |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.006218359 |
# |    clip_fraction        | 0.055       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.122       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0424      |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00667    |
# |    value_loss           | 0.0775      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.76        |
# |    ep_rew_mean          | 0.945       |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 484         |
# |    time_elapsed         | 2323        |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.010453924 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.22       |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0107      |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.79        |
# |    ep_rew_mean          | 0.97        |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 485         |
# |    time_elapsed         | 2328        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.009538434 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.225      |
# |    explained_variance   | 0.0528      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.284       |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 0.498       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.9         |
# |    ep_rew_mean          | 0.565       |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 486         |
# |    time_elapsed         | 2333        |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.007070592 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.106       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00314    |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.00932    |
# |    value_loss           | 0.0556      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.57        |
# |    ep_rew_mean          | 0.94        |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 487         |
# |    time_elapsed         | 2338        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.005800694 |
# |    clip_fraction        | 0.0349      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.219      |
# |    explained_variance   | 0.0657      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.05        |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00993    |
# |    value_loss           | 1.56        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 3.72        |
# |    ep_rew_mean          | 0.93        |
# | time/                   |             |
# |    fps                  | 426         |
# |    iterations           | 488         |
# |    time_elapsed         | 2342        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.004915833 |
# |    clip_fraction        | 0.0372      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.175      |
# |    explained_variance   | -0.454      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0604      |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | -0.00878    |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 3.81         |
# |    ep_rew_mean          | 0.935        |
# | time/                   |              |
# |    fps                  | 426          |
# |    iterations           | 489          |
# |    time_elapsed         | 2347         |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0048149787 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.202       |
# |    explained_variance   | 0.108        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.366        |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00591     |
# |    value_loss           | 0.305        |
# ------------------------------------------

# %%
from stable_baselines3.common.evaluation import evaluate_policy

# Evaluar el rendimiento del modelo entrenado
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)

print(f"Recompensa media: {mean_reward} +/- {std_reward}")
# Out:
# Recompensa media: 1.0 +/- 0.0
# c:\Users\usuario\anaconda3\envs\env_101\Lib\site-packages\stable_baselines3\common\evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(

# %%
# env.opponent = 'human'
# model.learn(total_timesteps=1)

# %% [markdown]
# # Test and train

# %%
import tkinter as tk
from tkinter import messagebox

def play_against_human_ui(model, env):
    # Inicializar el estado del juego
    obs, _ = env.reset()
    done = False

    # Crear la ventana principal
    root = tk.Tk()
    root.title("Tres en Raya - Juega contra el Agente")

    # Crear una lista para almacenar los botones
    buttons = []

    # Función para actualizar el tablero en la interfaz gráfica
    def update_board():
        env.render()
        board = env.board.get_board()
        symbols = {1: 'X', -1: 'O', 0: ' '}
        for i in range(9):
            buttons[i]['text'] = symbols[board[i]]
            if board[i] != 0:
                buttons[i]['state'] = 'disabled'
            else:
                buttons[i]['state'] = 'normal'

    # Función para manejar el clic del usuario
    def on_button_click(i):
        nonlocal obs, done
        if not done and env.current_player == -env.agent_player:
            action = i
            if action in env.board.get_empty_pos():
                print(f"El humano juega en la posición {action + 1}")
                obs, reward, done, _, _ = env.step(action)
                update_board()
                if done:
                    end_game(reward)
                else:
                    # Turno del agente
                    root.after(100, agent_turn)
            else:
                messagebox.showwarning("Movimiento inválido", "Esta posición ya está ocupada.")

    # Función para el turno del agente
    def agent_turn():
        nonlocal obs, done
        if not done and env.current_player == env.agent_player:
            while True:
                action, _states = model.predict(obs, deterministic=True)
                obs, reward, done, _, _ = env.step(action)
                if reward == -2 and not done:
                    # El agente hizo una acción inválida, intentará de nuevo
                    print(f"El agente intentó una acción inválida en la posición {action + 1}. Intentando de nuevo.")
                    continue
                else:
                    print(f"El agente juega en la posición {action + 1}. R: {reward}")
                    update_board()
                    if done:
                        end_game(reward)
                    break

    # Función para manejar el final del juego
    def end_game(reward):
        if reward == 1:
            messagebox.showinfo("Fin del juego", "¡El agente ha ganado!")
        elif reward == -1:
            messagebox.showinfo("Fin del juego", "¡Has ganado!")
        else:
            messagebox.showinfo("Fin del juego", "Es un empate.")
        
        # Esto no tiene efecto, ya que está pegado al entorno random: model.learn(total_timesteps=1)
        root.destroy()

    # Crear los botones del tablero
    for i in range(9):
        button = tk.Button(root, text=' ', font=('Helvetica', 32), width=5, height=2,
                           command=lambda i=i: on_button_click(i))
        button.grid(row=i // 3, column=i % 3)
        buttons.append(button)

    # Comenzar el juego: si el agente inicia, realiza su movimiento
    if env.current_player == env.agent_player:
        agent_turn()

    # Actualizar el tablero inicialmente
    update_board()

    # Ejecutar la interfaz gráfica
    root.mainloop()

# %%
def play_against_human(model, env):
    obs, _ = env.reset()
    done = False
    env.render()
    while not done:
        if env.current_player == env.agent_player:
            # Turno del agente
            while True:
                action, _states = model.predict(obs, deterministic=True)
                obs, reward, done, _, info = env.step(action)
                if reward == -2 and not done:
                    # El agente hizo una acción inválida, lo intentará de nuevo
                    print(f"El agente intentó una acción inválida en la posición {action + 1}. Intentando de nuevo.")
                    # Opcionalmente, puedes hacer que el agente aprenda de este error
                    continue  # El agente vuelve a intentar
                else:
                    print(f"El agente juega en la posición {action + 1}. R: {reward}")
                    env.render()
                    break  # El agente realizó un movimiento válido
        else:
            # Turno del humano
            valid_move = False
            while not valid_move:
                try:
                    action = int(input("Elige una posición (1-9): ")) - 1
                    if action in env.board.get_empty_pos():
                        valid_move = True
                    else:
                        print(f"Movimiento inválido. Intenta nuevamente. Action selected: {action}")
                except ValueError:
                    print("Entrada inválida. Por favor ingresa un número del 1 al 9.")
                    
            print(f"El humano juega en la posición {action + 1}")
            obs, reward, done, _, info = env.step(action)
            env.render()
        if done:
            env.render()
            if reward == 1:
                print("¡El agente ha ganado!")
            elif reward == -1:
                print("¡Has ganado!")
            else:
                print("Es un empate.")
            # Actualizamos el modelo para que continúe aprendiendo
            model.learn(total_timesteps=1)
            break

# %%
# Cargar el modelo entrenado
model = PPO.load("ppo_tictactoe_1M", env=env)

# Crear un nuevo entorno para jugar contra el humano
human_env = TicTacToeEnv(opponent='human')

# Jugar contra el humano y continuar aprendiendo
play_against_human_ui(model, human_env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# El humano juega en la posición 9
# . | . | .
# --+---+--
# . | . | .
# --+---+--
# . | X | O
#
# El humano juega en la posición 6
# . | . | .
# --+---+--
# . | X | O
# --+---+--
# . | X | O
#
# El agente juega en la posición 2. R: 1
# . | X | .
# --+---+--
# . | X | O
# --+---+--
# . | X | O
#
# El agente juega en la posición 5. R: 1
# . | X | .
# --+---+--
# . | X | X
# --+---+--
# . | X | O
#
# El agente juega en la posición 8. R: 1
# . | X | .
# --+---+--
# . | X | X
# --+---+--
# . | X | O
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py", line 861, in callit
#     func(*args)
#   File "C:\Users\usuario\AppData\Local\Temp\ipykernel_25016\888047381.py", line 58, in agent_turn
#     update_board()
#   File "C:\Users\usuario\AppData\Local\Temp\ipykernel_25016\888047381.py", line 22, in update_board
#     buttons[i]['text'] = symbols[board[i]]
#     ~~~~~~~~~~^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py", line 1732, in __setitem__
#     self.configure({key: value})
#   File "c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py", line 1721, in configure
#     return self._configure('configure', cnf, kw)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py", line 1711, in _configure
#     self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
# _tkinter.TclError: invalid command name ".!button"
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[9], line 8
#       5 human_env = TicTacToeEnv(opponent='human')
#       7 # Jugar contra el humano y continuar aprendiendo
# ----> 8 play_against_human_ui(model, human_env)
#
# Cell In[7], line 84, in play_against_human_ui(model, env)
#      82 # Comenzar el juego: si el agente inicia, realiza su movimiento
#      83 if env.current_player == env.agent_player:
# ---> 84     agent_turn()
#      86 # Actualizar el tablero inicialmente
#      87 update_board()
#
# Cell In[7], line 58, in play_against_human_ui.<locals>.agent_turn()
#      56 else:
#      57     print(f"El agente juega en la posición {action + 1}. R: {reward}")
# ---> 58     update_board()
#      59     if done:
#      60         end_game(reward)
#
# Cell In[7], line 22, in play_against_human_ui.<locals>.update_board()
#      20 symbols = {1: 'X', -1: 'O', 0: ' '}
#      21 for i in range(9):
# ---> 22     buttons[i]['text'] = symbols[board[i]]
#      23     if board[i] != 0:
#      24         buttons[i]['state'] = 'disabled'
#
# File c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py:1732, in Misc.__setitem__(self, key, value)
#    1731 def __setitem__(self, key, value):
# -> 1732     self.configure({key: value})
#
# File c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py:1721, in Misc.configure(self, cnf, **kw)
#    1714 def configure(self, cnf=None, **kw):
#    1715     """Configure resources of a widget.
#    1716
#    1717     The values for resources are specified as keyword
#    1718     arguments. To get an overview about
#    1719     the allowed keyword arguments call the method keys.
#    1720     """
# -> 1721     return self._configure('configure', cnf, kw)
#
# File c:\Users\usuario\anaconda3\envs\env_101\Lib\tkinter\__init__.py:1711, in Misc._configure(self, cmd, cnf, kw)
#    1709 if isinstance(cnf, str):
#    1710     return self._getconfigure1(_flatten((self._w, cmd, '-'+cnf)))
# -> 1711 self.tk.call(_flatten((self._w, cmd)) + self._options(cnf))
#
# TclError: invalid command name ".!button"

# %%
# Cargar el modelo entrenado
model = PPO.load("ppo_tictactoe", env=env)

# Crear un nuevo entorno para jugar contra el humano
human_env = TicTacToeEnv(opponent='human')

# Jugar contra el humano y continuar aprendiendo
play_against_human(model, human_env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# . | . | .
# --+---+--
# . | . | .
# --+---+--
# . | . | .
#
# El humano juega en la posición 1
# O | . | .
# --+---+--
# . | . | .
# --+---+--
# . | . | .
#
# El agente juega en la posición 7. R: 0
# O | . | .
# --+---+--
# . | . | .
# --+---+--
# X | . | .
#
# El humano juega en la posición 2
# O | O | .
# --+---+--
# . | . | .
# --+---+--
# X | . | .
#
# El agente juega en la posición 5. R: 0
# O | O | .
# --+---+--
# . | X | .
# --+---+--
# X | . | .
#
# Movimiento inválido. Intenta nuevamente. Action selected: 1
# El humano juega en la posición 4
# O | O | .
# --+---+--
# O | X | .
# --+---+--
# X | . | .
#
# El agente juega en la posición 3. R: 1
# O | O | X
# --+---+--
# O | X | .
# --+---+--
# X | . | .
#
# O | O | X
# --+---+--
# O | X | .
# --+---+--
# X | . | .
#
# ¡El agente ha ganado!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.89     |
# |    ep_rew_mean     | 0.565    |
# | time/              |          |
# |    fps             | 643      |
# |    iterations      | 1        |
# |    time_elapsed    | 3        |
# |    total_timesteps | 2048     |
# ---------------------------------
